# %% [markdown]
# # Load packages

# %%
import dacy
import os
import json
import copy
import re
import glob
import pandas as pd
from collections import Counter
from spacy.tokens import DocBin, Doc, Span
from spacy.training.corpus import Corpus
from itertools import combinations
from utils import *

# %% [markdown]
# # Load data

# %%
# Change cwd
os.chdir("/Users/emiltrencknerjessen/Desktop/priv/DANSK-gold-NER")

# Load language object
nlp = dacy.load("medium")

# List relevant data and sort by rater number
data_paths = glob.glob("./data/DANSK-multi/unprocessed/rater*/data.spacy")
data_paths.sort()
data_paths.sort(key="./data/DANSK-multi/unprocessed/rater_10/data.spacy".__eq__)

# Load in data and get rater indices (if not already loaded)
data = []
raters_idx = []
for path in data_paths:
    # Get rater indices
    rater_idx = re.search(r"\d+", path).group()
    raters_idx.append(int(rater_idx) - 1)

    # Load data
    doc_bin = DocBin().from_disk(path)
    docs = list(doc_bin.get_docs(nlp.vocab))[:20]
    data.append(docs)
# Out:
# /Users/emiltrencknerjessen/miniconda3/envs/thesis/lib/python3.10/site-packages/spacy/util.py:833: UserWarning: [W095] Model 'da_dacy_medium_trf' (0.1.0) was trained with spaCy v3.1 and may not be 100% compatible with the current version (3.2.4). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# /Users/emiltrencknerjessen/miniconda3/envs/thesis/lib/python3.10/site-packages/spacy_transformers/pipeline_component.py:406: UserWarning: Automatically converting a transformer component from spacy-transformers v1.0 to v1.1+. If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spacy-transformers version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %% [markdown]
# # Excluding rater 2, 7 and 10

# %%
# Define indexes for raters to exclude
indexes = [1, 7, 9]

# For each index in reverse order, remove them from the data
for index in sorted(indexes, reverse=True):
    del data[index]

# Update raters indexes
raters_idx = raters_idx[:7]

# Have a lookup table for the index vs. rater number.
raters_lookup = {0: 1, 1: 3, 2: 4, 3: 5, 4: 6, 5: 7, 6: 9}

# Keys = index
# Value = rater

# %% [markdown]
# # Retrieve unique documents and flat list with all docs from all raters

# %%
# Get a list with all docs from all raters (including duplicate docs)
all_docs = [item for sublist in data for item in sublist]

# Get a list of all unique docs
unique_docs = []
for doc in all_docs:
    if all(doc.text != unique_doc.text for unique_doc in unique_docs):
        unique_docs.append(copy.deepcopy(doc))

# Ensure that unique_docs don't already have entities
for i in unique_docs:
    i.ents = ()

# %% [markdown]
# # Streamline all docs for all raters

# %%
threshold_freq = .25
threshold_infreq = .2
n_raters = len(raters_idx)

streamlined_data = []

for rater_idx in raters_idx:
    streamlined_rater_docs = []
    rater_docs = copy.deepcopy(data[rater_idx])
    for doc in unique_docs:
        if get_same_doc_index(doc, rater_docs) is None: 
            print('Doc does not exist for rater')
        else:
            unique_ents_full_match,unique_ents_partial_match,freq_unique_ents_full_match,infreq_unique_ents_partial_match,unique_ents_full_match_ratio,unique_ents_partial_match_ratio = retrieve_freq_and_infreq_ents_from_doc(doc, all_docs, threshold_freq, threshold_infreq)
            streamlined_doc = streamline_doc(doc, rater_docs, freq_unique_ents_full_match, infreq_unique_ents_partial_match)
            print(f'Current rater: {raters_lookup[rater_idx]}')
            print(f'Current rater_idx: {rater_idx}')
            
            print(f'Current doc index in rater: {get_same_doc_index(doc, rater_docs)}')
            print(f'Current doc: {doc}')
            
            print(f'Unique_ents_full: {unique_ents_full_match}')
            print(f'Unique_ents_full ratio: {unique_ents_full_match_ratio}')
            print(f'Freq ents (no duplicates): {freq_unique_ents_full_match}')
            
            print(f'Unique_ents_partial: {unique_ents_partial_match}')
            print(f'Unique_ents_partial ratio: {unique_ents_partial_match_ratio}')
            print(f'Infreq ents (no overlaps): {infreq_unique_ents_partial_match}')
            
            print(f'Current doc ents PRIOR to streamlining: {rater_docs[get_same_doc_index(doc, rater_docs)].ents}')
            print(f'Current doc ents AFTER streamlining: {streamlined_doc.ents}')
        print('\n\n\n')

        if streamlined_doc != None:
            streamlined_rater_docs.append(streamlined_doc)
    streamlined_data.append(streamlined_rater_docs)
# Out:
# Current rater: 1
# Current rater_idx: 0
# Current doc index in rater: 0
# Current doc: Hvordan kan statsministeren kalde børn,der er født på danske hospitaler for indvandrerdrenge!
# Unique_ents_full: [danske, statsministeren, hospitaler, indvandrerdrenge]
# Unique_ents_full ratio: [1.0, 0.2857142857142857, 0.2857142857142857, 0.2857142857142857]
# Freq ents (no duplicates): [danske, statsministeren, hospitaler, indvandrerdrenge]
# Unique_ents_partial: [danske, statsministeren, hospitaler, indvandrerdrenge]
# Unique_ents_partial ratio: [1.0, 0.2857142857142857, 0.2857142857142857, 0.2857142857142857]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (danske,)
# Current doc ents AFTER streamlining: (statsministeren, danske, hospitaler, indvandrerdrenge)
#
#
#
#
# Current rater: 1
# Current rater_idx: 0
# Current doc index in rater: 1
# Current doc: Det her er jo håbløst #dkpol  https://t.co/e7hAg155Gw
# Unique_ents_full: [dkpol, #dkpol]
# Unique_ents_full ratio: [0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): []
# Unique_ents_partial: [dkpol, #dkpol]
# Unique_ents_partial ratio: [0.14285714285714285, 0.14285714285714285]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 1
# Current rater_idx: 0
# Current doc index in rater: 2
# Current doc:
# @cekicozlem
# Unique_ents_full: [@cekicozlem]
# Unique_ents_full ratio: [1.0]
# Freq ents (no duplicates): [@cekicozlem]
# Unique_ents_partial: [@cekicozlem]
# Unique_ents_partial ratio: [1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (@cekicozlem,)
# Current doc ents AFTER streamlining: (@cekicozlem,)
#
#
#
#
# Current rater: 1
# Current rater_idx: 0
# Current doc index in rater: 3
# Current doc: Da jeg voksede op ude i vollsmose, kaldte man dem 2. Generationsindvandrere.
# Unique_ents_full: [vollsmose, vollsmose, 2., 2. Generationsindvandrere., 2., 2. Generationsindvandrere]
# Unique_ents_full ratio: [0.42857142857142855, 0.5714285714285714, 0.2857142857142857, 0.14285714285714285, 0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): [2.]
# Unique_ents_partial: [vollsmose, 2., 2. Generationsindvandrere., 2. Generationsindvandrere]
# Unique_ents_partial ratio: [1.0, 0.42857142857142855, 0.14285714285714285, 0.14285714285714285]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (vollsmose,)
# Current doc ents AFTER streamlining: (vollsmose, 2.)
#
#
#
#
# Current rater: 1
# Current rater_idx: 0
# Current doc index in rater: 4
# Current doc: Vi må så være på 3. Generation nu?
# Unique_ents_full: [3., 3., 3. Generation]
# Unique_ents_full ratio: [0.2857142857142857, 0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): [3.]
# Unique_ents_partial: [3., 3. Generation]
# Unique_ents_partial ratio: [0.42857142857142855, 0.14285714285714285]
# Infreq ents (no overlaps): [3. Generation]
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: (3.,)
#
#
#
#
# Current rater: 1
# Current rater_idx: 0
# Current doc index in rater: 5
# Current doc: Åndssvagt ord, som ingen problemer løser.
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 1
# Current rater_idx: 0
# Current doc index in rater: 6
# Current doc: For der ér problemer blandt disse sociale lag, og dem kommer vi først rigtig til livs når vi kigger lidt bag tæppet
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 1
# Current rater_idx: 0
# Current doc index in rater: 7
# Current doc: Man kunne spørge sig selv, hvad dee mon ligger til grund for at så mange går ud af den kriminelle sti - som om de intet har at miste - kunne det tænkes at dk lod dem og deres forældre i stikken da de startede deres nye liv her?
# Unique_ents_full: [dk]
# Unique_ents_full ratio: [1.0]
# Freq ents (no duplicates): [dk]
# Unique_ents_partial: [dk]
# Unique_ents_partial ratio: [1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (dk,)
# Current doc ents AFTER streamlining: (dk,)
#
#
#
#
# Current rater: 1
# Current rater_idx: 0
# Current doc index in rater: 8
# Current doc: Man kunne også spørge om det mon er os eller dem som har skabt disse parallelsamfund.
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 1
# Current rater_idx: 0
# Current doc index in rater: 9
# Current doc: Hvem har besluttet at internere alle udefrakommende i disse nedslidte boligområder, vi i dag kalder for ghettoer?
# Unique_ents_full: [udefrakommende, boligområder, ghettoer, i, dag]
# Unique_ents_full ratio: [0.14285714285714285, 0.14285714285714285, 0.2857142857142857, 0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): [ghettoer]
# Unique_ents_partial: [udefrakommende, boligområder, ghettoer, i, dag]
# Unique_ents_partial ratio: [0.14285714285714285, 0.14285714285714285, 0.2857142857142857, 0.14285714285714285, 0.14285714285714285]
# Infreq ents (no overlaps): [udefrakommende, boligområder, i, dag]
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: (ghettoer,)
#
#
#
#
# Current rater: 1
# Current rater_idx: 0
# Current doc index in rater: 10
# Current doc: Gav man dem mulighed for at bo andre steder?
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 1
# Current rater_idx: 0
# Current doc index in rater: 11
# Current doc: Nå nej
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 1
# Current rater_idx: 0
# Current doc index in rater: 12
# Current doc: Det er selvfølgelig anekdotisk, men jeg har mødt så mange gode mennesker i min barndom som både hed Abdi, Tarik, Muhammad og Eyman.
# Unique_ents_full: [Abdi, Tarik, Muhammad, Eyman]
# Unique_ents_full ratio: [1.0, 1.0, 1.0, 1.0]
# Freq ents (no duplicates): [Abdi, Tarik, Muhammad, Eyman]
# Unique_ents_partial: [Abdi, Tarik, Muhammad, Eyman]
# Unique_ents_partial ratio: [1.0, 1.0, 1.0, 1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (Abdi, Tarik, Muhammad, Eyman)
# Current doc ents AFTER streamlining: (Abdi, Tarik, Muhammad, Eyman)
#
#
#
#
# Current rater: 1
# Current rater_idx: 0
# Current doc index in rater: 13
# Current doc: Varme hjerter, svære kår, gode til fodbold.
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 1
# Current rater_idx: 0
# Current doc index in rater: 14
# Current doc: Flere af dem sælger hash osv i dag.
# Unique_ents_full: [dag, i]
# Unique_ents_full ratio: [0.2857142857142857, 0.14285714285714285]
# Freq ents (no duplicates): [dag]
# Unique_ents_partial: [dag, i]
# Unique_ents_partial ratio: [0.2857142857142857, 0.14285714285714285]
# Infreq ents (no overlaps): [i]
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: (dag,)
#
#
#
#
# Current rater: 1
# Current rater_idx: 0
# Current doc index in rater: 15
# Current doc: Så sørgeligt og jeg nægter tesen om at det skulle være selvforskyldt
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 1
# Current rater_idx: 0
# Current doc index in rater: 16
# Current doc: Deres forældre havde ingen muligheder, allerede dengang blev de set ned på i samfundet, på kommunen og i parlamentet.
# Unique_ents_full: [kommunen, parlamentet, dengang]
# Unique_ents_full ratio: [0.2857142857142857, 0.42857142857142855, 0.14285714285714285]
# Freq ents (no duplicates): [kommunen, parlamentet]
# Unique_ents_partial: [kommunen, parlamentet, dengang]
# Unique_ents_partial ratio: [0.2857142857142857, 0.42857142857142855, 0.14285714285714285]
# Infreq ents (no overlaps): [dengang]
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: (kommunen, parlamentet)
#
#
#
#
# Current rater: 1
# Current rater_idx: 0
# Current doc index in rater: 17
# Current doc: Svært at gro blomster direkte på beton
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 1
# Current rater_idx: 0
# Current doc index in rater: 18
# Current doc:
# @iNSiG9FiX @cekicozlem
# Unique_ents_full: [@iNSiG9FiX, @cekicozlem]
# Unique_ents_full ratio: [1.0, 1.0]
# Freq ents (no duplicates): [@iNSiG9FiX, @cekicozlem]
# Unique_ents_partial: [@iNSiG9FiX, @cekicozlem]
# Unique_ents_partial ratio: [1.0, 1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (@iNSiG9FiX, @cekicozlem)
# Current doc ents AFTER streamlining: (@iNSiG9FiX, @cekicozlem)
#
#
#
#
# Current rater: 1
# Current rater_idx: 0
# Current doc index in rater: 19
# Current doc: Deres forældre, bedsteforældre er det vel snarere nu, de havde alle de muligheder de valgte at forfølge.
# Unique_ents_full: [nu]
# Unique_ents_full ratio: [0.14285714285714285]
# Freq ents (no duplicates): []
# Unique_ents_partial: [nu]
# Unique_ents_partial ratio: [0.14285714285714285]
# Infreq ents (no overlaps): [nu]
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Doc does not exist for rater
#
#
#
#
# Current rater: 3
# Current rater_idx: 1
# Current doc index in rater: 0
# Current doc: Hvordan kan statsministeren kalde børn,der er født på danske hospitaler for indvandrerdrenge!
# Unique_ents_full: [danske, statsministeren, hospitaler, indvandrerdrenge]
# Unique_ents_full ratio: [1.0, 0.2857142857142857, 0.2857142857142857, 0.2857142857142857]
# Freq ents (no duplicates): [danske, statsministeren, hospitaler, indvandrerdrenge]
# Unique_ents_partial: [danske, statsministeren, hospitaler, indvandrerdrenge]
# Unique_ents_partial ratio: [1.0, 0.2857142857142857, 0.2857142857142857, 0.2857142857142857]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (statsministeren, danske, hospitaler)
# Current doc ents AFTER streamlining: (statsministeren, danske, hospitaler, indvandrerdrenge)
#
#
#
#
# Current rater: 3
# Current rater_idx: 1
# Current doc index in rater: 1
# Current doc: Det her er jo håbløst #dkpol  https://t.co/e7hAg155Gw
# Unique_ents_full: [dkpol, #dkpol]
# Unique_ents_full ratio: [0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): []
# Unique_ents_partial: [dkpol, #dkpol]
# Unique_ents_partial ratio: [0.14285714285714285, 0.14285714285714285]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 3
# Current rater_idx: 1
# Current doc index in rater: 2
# Current doc:
# @cekicozlem
# Unique_ents_full: [@cekicozlem]
# Unique_ents_full ratio: [1.0]
# Freq ents (no duplicates): [@cekicozlem]
# Unique_ents_partial: [@cekicozlem]
# Unique_ents_partial ratio: [1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (@cekicozlem,)
# Current doc ents AFTER streamlining: (@cekicozlem,)
#
#
#
#
# Current rater: 3
# Current rater_idx: 1
# Current doc index in rater: 3
# Current doc: Da jeg voksede op ude i vollsmose, kaldte man dem 2. Generationsindvandrere.
# Unique_ents_full: [vollsmose, vollsmose, 2., 2. Generationsindvandrere., 2., 2. Generationsindvandrere]
# Unique_ents_full ratio: [0.42857142857142855, 0.5714285714285714, 0.2857142857142857, 0.14285714285714285, 0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): [2.]
# Unique_ents_partial: [vollsmose, 2., 2. Generationsindvandrere., 2. Generationsindvandrere]
# Unique_ents_partial ratio: [1.0, 0.42857142857142855, 0.14285714285714285, 0.14285714285714285]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (vollsmose, 2.)
# Current doc ents AFTER streamlining: (vollsmose, 2.)
#
#
#
#
# Current rater: 3
# Current rater_idx: 1
# Current doc index in rater: 4
# Current doc: Vi må så være på 3. Generation nu?
# Unique_ents_full: [3., 3., 3. Generation]
# Unique_ents_full ratio: [0.2857142857142857, 0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): [3.]
# Unique_ents_partial: [3., 3. Generation]
# Unique_ents_partial ratio: [0.42857142857142855, 0.14285714285714285]
# Infreq ents (no overlaps): [3. Generation]
# Current doc ents PRIOR to streamlining: (3.,)
# Current doc ents AFTER streamlining: (3.,)
#
#
#
#
# Current rater: 3
# Current rater_idx: 1
# Current doc index in rater: 5
# Current doc: Åndssvagt ord, som ingen problemer løser.
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 3
# Current rater_idx: 1
# Current doc index in rater: 6
# Current doc: For der ér problemer blandt disse sociale lag, og dem kommer vi først rigtig til livs når vi kigger lidt bag tæppet
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 3
# Current rater_idx: 1
# Current doc index in rater: 7
# Current doc: Man kunne spørge sig selv, hvad dee mon ligger til grund for at så mange går ud af den kriminelle sti - som om de intet har at miste - kunne det tænkes at dk lod dem og deres forældre i stikken da de startede deres nye liv her?
# Unique_ents_full: [dk]
# Unique_ents_full ratio: [1.0]
# Freq ents (no duplicates): [dk]
# Unique_ents_partial: [dk]
# Unique_ents_partial ratio: [1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (dk,)
# Current doc ents AFTER streamlining: (dk,)
#
#
#
#
# Current rater: 3
# Current rater_idx: 1
# Current doc index in rater: 8
# Current doc: Man kunne også spørge om det mon er os eller dem som har skabt disse parallelsamfund.
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 3
# Current rater_idx: 1
# Current doc index in rater: 9
# Current doc: Hvem har besluttet at internere alle udefrakommende i disse nedslidte boligområder, vi i dag kalder for ghettoer?
# Unique_ents_full: [udefrakommende, boligområder, ghettoer, i, dag]
# Unique_ents_full ratio: [0.14285714285714285, 0.14285714285714285, 0.2857142857142857, 0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): [ghettoer]
# Unique_ents_partial: [udefrakommende, boligområder, ghettoer, i, dag]
# Unique_ents_partial ratio: [0.14285714285714285, 0.14285714285714285, 0.2857142857142857, 0.14285714285714285, 0.14285714285714285]
# Infreq ents (no overlaps): [udefrakommende, boligområder, i, dag]
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: (ghettoer,)
#
#
#
#
# Current rater: 3
# Current rater_idx: 1
# Current doc index in rater: 10
# Current doc: Gav man dem mulighed for at bo andre steder?
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 3
# Current rater_idx: 1
# Current doc index in rater: 11
# Current doc: Nå nej
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 3
# Current rater_idx: 1
# Current doc index in rater: 12
# Current doc: Det er selvfølgelig anekdotisk, men jeg har mødt så mange gode mennesker i min barndom som både hed Abdi, Tarik, Muhammad og Eyman.
# Unique_ents_full: [Abdi, Tarik, Muhammad, Eyman]
# Unique_ents_full ratio: [1.0, 1.0, 1.0, 1.0]
# Freq ents (no duplicates): [Abdi, Tarik, Muhammad, Eyman]
# Unique_ents_partial: [Abdi, Tarik, Muhammad, Eyman]
# Unique_ents_partial ratio: [1.0, 1.0, 1.0, 1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (Abdi, Tarik, Muhammad, Eyman)
# Current doc ents AFTER streamlining: (Abdi, Tarik, Muhammad, Eyman)
#
#
#
#
# Current rater: 3
# Current rater_idx: 1
# Current doc index in rater: 13
# Current doc: Varme hjerter, svære kår, gode til fodbold.
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 3
# Current rater_idx: 1
# Current doc index in rater: 14
# Current doc: Flere af dem sælger hash osv i dag.
# Unique_ents_full: [dag, i]
# Unique_ents_full ratio: [0.2857142857142857, 0.14285714285714285]
# Freq ents (no duplicates): [dag]
# Unique_ents_partial: [dag, i]
# Unique_ents_partial ratio: [0.2857142857142857, 0.14285714285714285]
# Infreq ents (no overlaps): [i]
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: (dag,)
#
#
#
#
# Current rater: 3
# Current rater_idx: 1
# Current doc index in rater: 15
# Current doc: Så sørgeligt og jeg nægter tesen om at det skulle være selvforskyldt
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 3
# Current rater_idx: 1
# Current doc index in rater: 16
# Current doc: Deres forældre havde ingen muligheder, allerede dengang blev de set ned på i samfundet, på kommunen og i parlamentet.
# Unique_ents_full: [kommunen, parlamentet, dengang]
# Unique_ents_full ratio: [0.2857142857142857, 0.42857142857142855, 0.14285714285714285]
# Freq ents (no duplicates): [kommunen, parlamentet]
# Unique_ents_partial: [kommunen, parlamentet, dengang]
# Unique_ents_partial ratio: [0.2857142857142857, 0.42857142857142855, 0.14285714285714285]
# Infreq ents (no overlaps): [dengang]
# Current doc ents PRIOR to streamlining: (kommunen, parlamentet)
# Current doc ents AFTER streamlining: (kommunen, parlamentet)
#
#
#
#
# Current rater: 3
# Current rater_idx: 1
# Current doc index in rater: 17
# Current doc: Svært at gro blomster direkte på beton
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 3
# Current rater_idx: 1
# Current doc index in rater: 18
# Current doc:
# @iNSiG9FiX @cekicozlem
# Unique_ents_full: [@iNSiG9FiX, @cekicozlem]
# Unique_ents_full ratio: [1.0, 1.0]
# Freq ents (no duplicates): [@iNSiG9FiX, @cekicozlem]
# Unique_ents_partial: [@iNSiG9FiX, @cekicozlem]
# Unique_ents_partial ratio: [1.0, 1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (@iNSiG9FiX, @cekicozlem)
# Current doc ents AFTER streamlining: (@iNSiG9FiX, @cekicozlem)
#
#
#
#
# Current rater: 3
# Current rater_idx: 1
# Current doc index in rater: 19
# Current doc: Deres forældre, bedsteforældre er det vel snarere nu, de havde alle de muligheder de valgte at forfølge.
# Unique_ents_full: [nu]
# Unique_ents_full ratio: [0.14285714285714285]
# Freq ents (no duplicates): []
# Unique_ents_partial: [nu]
# Unique_ents_partial ratio: [0.14285714285714285]
# Infreq ents (no overlaps): [nu]
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Doc does not exist for rater
#
#
#
#
# Current rater: 4
# Current rater_idx: 2
# Current doc index in rater: 0
# Current doc: Hvordan kan statsministeren kalde børn,der er født på danske hospitaler for indvandrerdrenge!
# Unique_ents_full: [danske, statsministeren, hospitaler, indvandrerdrenge]
# Unique_ents_full ratio: [1.0, 0.2857142857142857, 0.2857142857142857, 0.2857142857142857]
# Freq ents (no duplicates): [danske, statsministeren, hospitaler, indvandrerdrenge]
# Unique_ents_partial: [danske, statsministeren, hospitaler, indvandrerdrenge]
# Unique_ents_partial ratio: [1.0, 0.2857142857142857, 0.2857142857142857, 0.2857142857142857]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (statsministeren, danske, hospitaler, indvandrerdrenge)
# Current doc ents AFTER streamlining: (statsministeren, danske, hospitaler, indvandrerdrenge)
#
#
#
#
# Current rater: 4
# Current rater_idx: 2
# Current doc index in rater: 1
# Current doc: Det her er jo håbløst #dkpol  https://t.co/e7hAg155Gw
# Unique_ents_full: [dkpol, #dkpol]
# Unique_ents_full ratio: [0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): []
# Unique_ents_partial: [dkpol, #dkpol]
# Unique_ents_partial ratio: [0.14285714285714285, 0.14285714285714285]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 4
# Current rater_idx: 2
# Current doc index in rater: 2
# Current doc:
# @cekicozlem
# Unique_ents_full: [@cekicozlem]
# Unique_ents_full ratio: [1.0]
# Freq ents (no duplicates): [@cekicozlem]
# Unique_ents_partial: [@cekicozlem]
# Unique_ents_partial ratio: [1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (@cekicozlem,)
# Current doc ents AFTER streamlining: (@cekicozlem,)
#
#
#
#
# Current rater: 4
# Current rater_idx: 2
# Current doc index in rater: 3
# Current doc: Da jeg voksede op ude i vollsmose, kaldte man dem 2. Generationsindvandrere.
# Unique_ents_full: [vollsmose, vollsmose, 2., 2. Generationsindvandrere., 2., 2. Generationsindvandrere]
# Unique_ents_full ratio: [0.42857142857142855, 0.5714285714285714, 0.2857142857142857, 0.14285714285714285, 0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): [2.]
# Unique_ents_partial: [vollsmose, 2., 2. Generationsindvandrere., 2. Generationsindvandrere]
# Unique_ents_partial ratio: [1.0, 0.42857142857142855, 0.14285714285714285, 0.14285714285714285]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (vollsmose, 2. Generationsindvandrere.)
# Current doc ents AFTER streamlining: (vollsmose, 2.)
#
#
#
#
# Current rater: 4
# Current rater_idx: 2
# Current doc index in rater: 4
# Current doc: Vi må så være på 3. Generation nu?
# Unique_ents_full: [3., 3., 3. Generation]
# Unique_ents_full ratio: [0.2857142857142857, 0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): [3.]
# Unique_ents_partial: [3., 3. Generation]
# Unique_ents_partial ratio: [0.42857142857142855, 0.14285714285714285]
# Infreq ents (no overlaps): [3. Generation]
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: (3.,)
#
#
#
#
# Current rater: 4
# Current rater_idx: 2
# Current doc index in rater: 5
# Current doc: Åndssvagt ord, som ingen problemer løser.
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 4
# Current rater_idx: 2
# Current doc index in rater: 6
# Current doc: For der ér problemer blandt disse sociale lag, og dem kommer vi først rigtig til livs når vi kigger lidt bag tæppet
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 4
# Current rater_idx: 2
# Current doc index in rater: 7
# Current doc: Man kunne spørge sig selv, hvad dee mon ligger til grund for at så mange går ud af den kriminelle sti - som om de intet har at miste - kunne det tænkes at dk lod dem og deres forældre i stikken da de startede deres nye liv her?
# Unique_ents_full: [dk]
# Unique_ents_full ratio: [1.0]
# Freq ents (no duplicates): [dk]
# Unique_ents_partial: [dk]
# Unique_ents_partial ratio: [1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (dk,)
# Current doc ents AFTER streamlining: (dk,)
#
#
#
#
# Current rater: 4
# Current rater_idx: 2
# Current doc index in rater: 8
# Current doc: Man kunne også spørge om det mon er os eller dem som har skabt disse parallelsamfund.
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 4
# Current rater_idx: 2
# Current doc index in rater: 9
# Current doc: Hvem har besluttet at internere alle udefrakommende i disse nedslidte boligområder, vi i dag kalder for ghettoer?
# Unique_ents_full: [udefrakommende, boligområder, ghettoer, i, dag]
# Unique_ents_full ratio: [0.14285714285714285, 0.14285714285714285, 0.2857142857142857, 0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): [ghettoer]
# Unique_ents_partial: [udefrakommende, boligområder, ghettoer, i, dag]
# Unique_ents_partial ratio: [0.14285714285714285, 0.14285714285714285, 0.2857142857142857, 0.14285714285714285, 0.14285714285714285]
# Infreq ents (no overlaps): [udefrakommende, boligområder, i, dag]
# Current doc ents PRIOR to streamlining: (udefrakommende, boligområder, ghettoer)
# Current doc ents AFTER streamlining: (ghettoer,)
#
#
#
#
# Current rater: 4
# Current rater_idx: 2
# Current doc index in rater: 10
# Current doc: Gav man dem mulighed for at bo andre steder?
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 4
# Current rater_idx: 2
# Current doc index in rater: 11
# Current doc: Nå nej
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 4
# Current rater_idx: 2
# Current doc index in rater: 12
# Current doc: Det er selvfølgelig anekdotisk, men jeg har mødt så mange gode mennesker i min barndom som både hed Abdi, Tarik, Muhammad og Eyman.
# Unique_ents_full: [Abdi, Tarik, Muhammad, Eyman]
# Unique_ents_full ratio: [1.0, 1.0, 1.0, 1.0]
# Freq ents (no duplicates): [Abdi, Tarik, Muhammad, Eyman]
# Unique_ents_partial: [Abdi, Tarik, Muhammad, Eyman]
# Unique_ents_partial ratio: [1.0, 1.0, 1.0, 1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (Abdi, Tarik, Muhammad, Eyman)
# Current doc ents AFTER streamlining: (Abdi, Tarik, Muhammad, Eyman)
#
#
#
#
# Current rater: 4
# Current rater_idx: 2
# Current doc index in rater: 13
# Current doc: Varme hjerter, svære kår, gode til fodbold.
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 4
# Current rater_idx: 2
# Current doc index in rater: 14
# Current doc: Flere af dem sælger hash osv i dag.
# Unique_ents_full: [dag, i]
# Unique_ents_full ratio: [0.2857142857142857, 0.14285714285714285]
# Freq ents (no duplicates): [dag]
# Unique_ents_partial: [dag, i]
# Unique_ents_partial ratio: [0.2857142857142857, 0.14285714285714285]
# Infreq ents (no overlaps): [i]
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: (dag,)
#
#
#
#
# Current rater: 4
# Current rater_idx: 2
# Current doc index in rater: 15
# Current doc: Så sørgeligt og jeg nægter tesen om at det skulle være selvforskyldt
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 4
# Current rater_idx: 2
# Current doc index in rater: 16
# Current doc: Deres forældre havde ingen muligheder, allerede dengang blev de set ned på i samfundet, på kommunen og i parlamentet.
# Unique_ents_full: [kommunen, parlamentet, dengang]
# Unique_ents_full ratio: [0.2857142857142857, 0.42857142857142855, 0.14285714285714285]
# Freq ents (no duplicates): [kommunen, parlamentet]
# Unique_ents_partial: [kommunen, parlamentet, dengang]
# Unique_ents_partial ratio: [0.2857142857142857, 0.42857142857142855, 0.14285714285714285]
# Infreq ents (no overlaps): [dengang]
# Current doc ents PRIOR to streamlining: (kommunen, parlamentet)
# Current doc ents AFTER streamlining: (kommunen, parlamentet)
#
#
#
#
# Current rater: 4
# Current rater_idx: 2
# Current doc index in rater: 17
# Current doc: Svært at gro blomster direkte på beton
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 4
# Current rater_idx: 2
# Current doc index in rater: 18
# Current doc:
# @iNSiG9FiX @cekicozlem
# Unique_ents_full: [@iNSiG9FiX, @cekicozlem]
# Unique_ents_full ratio: [1.0, 1.0]
# Freq ents (no duplicates): [@iNSiG9FiX, @cekicozlem]
# Unique_ents_partial: [@iNSiG9FiX, @cekicozlem]
# Unique_ents_partial ratio: [1.0, 1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (@iNSiG9FiX, @cekicozlem)
# Current doc ents AFTER streamlining: (@iNSiG9FiX, @cekicozlem)
#
#
#
#
# Current rater: 4
# Current rater_idx: 2
# Current doc index in rater: 19
# Current doc: Deres forældre, bedsteforældre er det vel snarere nu, de havde alle de muligheder de valgte at forfølge.
# Unique_ents_full: [nu]
# Unique_ents_full ratio: [0.14285714285714285]
# Freq ents (no duplicates): []
# Unique_ents_partial: [nu]
# Unique_ents_partial ratio: [0.14285714285714285]
# Infreq ents (no overlaps): [nu]
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Doc does not exist for rater
#
#
#
#
# Current rater: 5
# Current rater_idx: 3
# Current doc index in rater: 0
# Current doc: Hvordan kan statsministeren kalde børn,der er født på danske hospitaler for indvandrerdrenge!
# Unique_ents_full: [danske, statsministeren, hospitaler, indvandrerdrenge]
# Unique_ents_full ratio: [1.0, 0.2857142857142857, 0.2857142857142857, 0.2857142857142857]
# Freq ents (no duplicates): [danske, statsministeren, hospitaler, indvandrerdrenge]
# Unique_ents_partial: [danske, statsministeren, hospitaler, indvandrerdrenge]
# Unique_ents_partial ratio: [1.0, 0.2857142857142857, 0.2857142857142857, 0.2857142857142857]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (danske,)
# Current doc ents AFTER streamlining: (statsministeren, danske, hospitaler, indvandrerdrenge)
#
#
#
#
# Current rater: 5
# Current rater_idx: 3
# Current doc index in rater: 1
# Current doc: Det her er jo håbløst #dkpol  https://t.co/e7hAg155Gw
# Unique_ents_full: [dkpol, #dkpol]
# Unique_ents_full ratio: [0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): []
# Unique_ents_partial: [dkpol, #dkpol]
# Unique_ents_partial ratio: [0.14285714285714285, 0.14285714285714285]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Doc does not exist for rater
#
#
#
#
# Current rater: 5
# Current rater_idx: 3
# Current doc index in rater: 2
# Current doc: Da jeg voksede op ude i vollsmose, kaldte man dem 2. Generationsindvandrere.
# Unique_ents_full: [vollsmose, vollsmose, 2., 2. Generationsindvandrere., 2., 2. Generationsindvandrere]
# Unique_ents_full ratio: [0.42857142857142855, 0.5714285714285714, 0.2857142857142857, 0.14285714285714285, 0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): [2.]
# Unique_ents_partial: [vollsmose, 2., 2. Generationsindvandrere., 2. Generationsindvandrere]
# Unique_ents_partial ratio: [1.0, 0.42857142857142855, 0.14285714285714285, 0.14285714285714285]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (vollsmose, 2.)
# Current doc ents AFTER streamlining: (vollsmose, 2.)
#
#
#
#
# Current rater: 5
# Current rater_idx: 3
# Current doc index in rater: 3
# Current doc: Vi må så være på 3. Generation nu?
# Unique_ents_full: [3., 3., 3. Generation]
# Unique_ents_full ratio: [0.2857142857142857, 0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): [3.]
# Unique_ents_partial: [3., 3. Generation]
# Unique_ents_partial ratio: [0.42857142857142855, 0.14285714285714285]
# Infreq ents (no overlaps): [3. Generation]
# Current doc ents PRIOR to streamlining: (3.,)
# Current doc ents AFTER streamlining: (3.,)
#
#
#
#
# Current rater: 5
# Current rater_idx: 3
# Current doc index in rater: 4
# Current doc: Åndssvagt ord, som ingen problemer løser.
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 5
# Current rater_idx: 3
# Current doc index in rater: 5
# Current doc: For der ér problemer blandt disse sociale lag, og dem kommer vi først rigtig til livs når vi kigger lidt bag tæppet
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 5
# Current rater_idx: 3
# Current doc index in rater: 6
# Current doc: Man kunne spørge sig selv, hvad dee mon ligger til grund for at så mange går ud af den kriminelle sti - som om de intet har at miste - kunne det tænkes at dk lod dem og deres forældre i stikken da de startede deres nye liv her?
# Unique_ents_full: [dk]
# Unique_ents_full ratio: [1.0]
# Freq ents (no duplicates): [dk]
# Unique_ents_partial: [dk]
# Unique_ents_partial ratio: [1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (dk,)
# Current doc ents AFTER streamlining: (dk,)
#
#
#
#
# Current rater: 5
# Current rater_idx: 3
# Current doc index in rater: 7
# Current doc: Man kunne også spørge om det mon er os eller dem som har skabt disse parallelsamfund.
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 5
# Current rater_idx: 3
# Current doc index in rater: 8
# Current doc: Hvem har besluttet at internere alle udefrakommende i disse nedslidte boligområder, vi i dag kalder for ghettoer?
# Unique_ents_full: [udefrakommende, boligområder, ghettoer, i, dag]
# Unique_ents_full ratio: [0.14285714285714285, 0.14285714285714285, 0.2857142857142857, 0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): [ghettoer]
# Unique_ents_partial: [udefrakommende, boligområder, ghettoer, i, dag]
# Unique_ents_partial ratio: [0.14285714285714285, 0.14285714285714285, 0.2857142857142857, 0.14285714285714285, 0.14285714285714285]
# Infreq ents (no overlaps): [udefrakommende, boligområder, i, dag]
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: (ghettoer,)
#
#
#
#
# Current rater: 5
# Current rater_idx: 3
# Current doc index in rater: 9
# Current doc: Gav man dem mulighed for at bo andre steder?
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 5
# Current rater_idx: 3
# Current doc index in rater: 10
# Current doc: Nå nej
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 5
# Current rater_idx: 3
# Current doc index in rater: 11
# Current doc: Det er selvfølgelig anekdotisk, men jeg har mødt så mange gode mennesker i min barndom som både hed Abdi, Tarik, Muhammad og Eyman.
# Unique_ents_full: [Abdi, Tarik, Muhammad, Eyman]
# Unique_ents_full ratio: [1.0, 1.0, 1.0, 1.0]
# Freq ents (no duplicates): [Abdi, Tarik, Muhammad, Eyman]
# Unique_ents_partial: [Abdi, Tarik, Muhammad, Eyman]
# Unique_ents_partial ratio: [1.0, 1.0, 1.0, 1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (Abdi, Tarik, Muhammad, Eyman)
# Current doc ents AFTER streamlining: (Abdi, Tarik, Muhammad, Eyman)
#
#
#
#
# Current rater: 5
# Current rater_idx: 3
# Current doc index in rater: 13
# Current doc: Varme hjerter, svære kår, gode til fodbold.
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 5
# Current rater_idx: 3
# Current doc index in rater: 12
# Current doc: Flere af dem sælger hash osv i dag.
# Unique_ents_full: [dag, i]
# Unique_ents_full ratio: [0.2857142857142857, 0.14285714285714285]
# Freq ents (no duplicates): [dag]
# Unique_ents_partial: [dag, i]
# Unique_ents_partial ratio: [0.2857142857142857, 0.14285714285714285]
# Infreq ents (no overlaps): [i]
# Current doc ents PRIOR to streamlining: (dag,)
# Current doc ents AFTER streamlining: (dag,)
#
#
#
#
# Current rater: 5
# Current rater_idx: 3
# Current doc index in rater: 14
# Current doc: Så sørgeligt og jeg nægter tesen om at det skulle være selvforskyldt
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 5
# Current rater_idx: 3
# Current doc index in rater: 15
# Current doc: Deres forældre havde ingen muligheder, allerede dengang blev de set ned på i samfundet, på kommunen og i parlamentet.
# Unique_ents_full: [kommunen, parlamentet, dengang]
# Unique_ents_full ratio: [0.2857142857142857, 0.42857142857142855, 0.14285714285714285]
# Freq ents (no duplicates): [kommunen, parlamentet]
# Unique_ents_partial: [kommunen, parlamentet, dengang]
# Unique_ents_partial ratio: [0.2857142857142857, 0.42857142857142855, 0.14285714285714285]
# Infreq ents (no overlaps): [dengang]
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: (kommunen, parlamentet)
#
#
#
#
# Current rater: 5
# Current rater_idx: 3
# Current doc index in rater: 16
# Current doc: Svært at gro blomster direkte på beton
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 5
# Current rater_idx: 3
# Current doc index in rater: 17
# Current doc:
# @iNSiG9FiX @cekicozlem
# Unique_ents_full: [@iNSiG9FiX, @cekicozlem]
# Unique_ents_full ratio: [1.0, 1.0]
# Freq ents (no duplicates): [@iNSiG9FiX, @cekicozlem]
# Unique_ents_partial: [@iNSiG9FiX, @cekicozlem]
# Unique_ents_partial ratio: [1.0, 1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (@iNSiG9FiX, @cekicozlem)
# Current doc ents AFTER streamlining: (@iNSiG9FiX, @cekicozlem)
#
#
#
#
# Current rater: 5
# Current rater_idx: 3
# Current doc index in rater: 18
# Current doc: Deres forældre, bedsteforældre er det vel snarere nu, de havde alle de muligheder de valgte at forfølge.
# Unique_ents_full: [nu]
# Unique_ents_full ratio: [0.14285714285714285]
# Freq ents (no duplicates): []
# Unique_ents_partial: [nu]
# Unique_ents_partial ratio: [0.14285714285714285]
# Infreq ents (no overlaps): [nu]
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 5
# Current rater_idx: 3
# Current doc index in rater: 19
# Current doc: Det er på tide man lægger offerrollen på hylden.
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 6
# Current rater_idx: 4
# Current doc index in rater: 0
# Current doc: Hvordan kan statsministeren kalde børn,der er født på danske hospitaler for indvandrerdrenge!
# Unique_ents_full: [danske, statsministeren, hospitaler, indvandrerdrenge]
# Unique_ents_full ratio: [1.0, 0.2857142857142857, 0.2857142857142857, 0.2857142857142857]
# Freq ents (no duplicates): [danske, statsministeren, hospitaler, indvandrerdrenge]
# Unique_ents_partial: [danske, statsministeren, hospitaler, indvandrerdrenge]
# Unique_ents_partial ratio: [1.0, 0.2857142857142857, 0.2857142857142857, 0.2857142857142857]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (danske,)
# Current doc ents AFTER streamlining: (statsministeren, danske, hospitaler, indvandrerdrenge)
#
#
#
#
# Current rater: 6
# Current rater_idx: 4
# Current doc index in rater: 1
# Current doc: Det her er jo håbløst #dkpol  https://t.co/e7hAg155Gw
# Unique_ents_full: [dkpol, #dkpol]
# Unique_ents_full ratio: [0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): []
# Unique_ents_partial: [dkpol, #dkpol]
# Unique_ents_partial ratio: [0.14285714285714285, 0.14285714285714285]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (dkpol,)
# Current doc ents AFTER streamlining: (dkpol,)
#
#
#
#
# Current rater: 6
# Current rater_idx: 4
# Current doc index in rater: 2
# Current doc:
# @cekicozlem
# Unique_ents_full: [@cekicozlem]
# Unique_ents_full ratio: [1.0]
# Freq ents (no duplicates): [@cekicozlem]
# Unique_ents_partial: [@cekicozlem]
# Unique_ents_partial ratio: [1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (@cekicozlem,)
# Current doc ents AFTER streamlining: (@cekicozlem,)
#
#
#
#
# Current rater: 6
# Current rater_idx: 4
# Current doc index in rater: 3
# Current doc: Da jeg voksede op ude i vollsmose, kaldte man dem 2. Generationsindvandrere.
# Unique_ents_full: [vollsmose, vollsmose, 2., 2. Generationsindvandrere., 2., 2. Generationsindvandrere]
# Unique_ents_full ratio: [0.42857142857142855, 0.5714285714285714, 0.2857142857142857, 0.14285714285714285, 0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): [2.]
# Unique_ents_partial: [vollsmose, 2., 2. Generationsindvandrere., 2. Generationsindvandrere]
# Unique_ents_partial ratio: [1.0, 0.42857142857142855, 0.14285714285714285, 0.14285714285714285]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (vollsmose, 2.)
# Current doc ents AFTER streamlining: (vollsmose, 2.)
#
#
#
#
# Current rater: 6
# Current rater_idx: 4
# Current doc index in rater: 4
# Current doc: Vi må så være på 3. Generation nu?
# Unique_ents_full: [3., 3., 3. Generation]
# Unique_ents_full ratio: [0.2857142857142857, 0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): [3.]
# Unique_ents_partial: [3., 3. Generation]
# Unique_ents_partial ratio: [0.42857142857142855, 0.14285714285714285]
# Infreq ents (no overlaps): [3. Generation]
# Current doc ents PRIOR to streamlining: (3.,)
# Current doc ents AFTER streamlining: (3.,)
#
#
#
#
# Current rater: 6
# Current rater_idx: 4
# Current doc index in rater: 5
# Current doc: Åndssvagt ord, som ingen problemer løser.
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 6
# Current rater_idx: 4
# Current doc index in rater: 6
# Current doc: For der ér problemer blandt disse sociale lag, og dem kommer vi først rigtig til livs når vi kigger lidt bag tæppet
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 6
# Current rater_idx: 4
# Current doc index in rater: 7
# Current doc: Man kunne spørge sig selv, hvad dee mon ligger til grund for at så mange går ud af den kriminelle sti - som om de intet har at miste - kunne det tænkes at dk lod dem og deres forældre i stikken da de startede deres nye liv her?
# Unique_ents_full: [dk]
# Unique_ents_full ratio: [1.0]
# Freq ents (no duplicates): [dk]
# Unique_ents_partial: [dk]
# Unique_ents_partial ratio: [1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (dk,)
# Current doc ents AFTER streamlining: (dk,)
#
#
#
#
# Current rater: 6
# Current rater_idx: 4
# Current doc index in rater: 8
# Current doc: Man kunne også spørge om det mon er os eller dem som har skabt disse parallelsamfund.
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 6
# Current rater_idx: 4
# Current doc index in rater: 9
# Current doc: Hvem har besluttet at internere alle udefrakommende i disse nedslidte boligområder, vi i dag kalder for ghettoer?
# Unique_ents_full: [udefrakommende, boligområder, ghettoer, i, dag]
# Unique_ents_full ratio: [0.14285714285714285, 0.14285714285714285, 0.2857142857142857, 0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): [ghettoer]
# Unique_ents_partial: [udefrakommende, boligområder, ghettoer, i, dag]
# Unique_ents_partial ratio: [0.14285714285714285, 0.14285714285714285, 0.2857142857142857, 0.14285714285714285, 0.14285714285714285]
# Infreq ents (no overlaps): [udefrakommende, boligområder, i, dag]
# Current doc ents PRIOR to streamlining: (i, dag)
# Current doc ents AFTER streamlining: (ghettoer,)
#
#
#
#
# Current rater: 6
# Current rater_idx: 4
# Current doc index in rater: 10
# Current doc: Gav man dem mulighed for at bo andre steder?
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 6
# Current rater_idx: 4
# Current doc index in rater: 11
# Current doc: Nå nej
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 6
# Current rater_idx: 4
# Current doc index in rater: 12
# Current doc: Det er selvfølgelig anekdotisk, men jeg har mødt så mange gode mennesker i min barndom som både hed Abdi, Tarik, Muhammad og Eyman.
# Unique_ents_full: [Abdi, Tarik, Muhammad, Eyman]
# Unique_ents_full ratio: [1.0, 1.0, 1.0, 1.0]
# Freq ents (no duplicates): [Abdi, Tarik, Muhammad, Eyman]
# Unique_ents_partial: [Abdi, Tarik, Muhammad, Eyman]
# Unique_ents_partial ratio: [1.0, 1.0, 1.0, 1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (Abdi, Tarik, Muhammad, Eyman)
# Current doc ents AFTER streamlining: (Abdi, Tarik, Muhammad, Eyman)
#
#
#
#
# Current rater: 6
# Current rater_idx: 4
# Current doc index in rater: 13
# ...
#
#
#
#
# Current rater: 7
# Current rater_idx: 5
# Current doc index in rater: 8
# Current doc: Hvem har besluttet at internere alle udefrakommende i disse nedslidte boligområder, vi i dag kalder for ghettoer?
# Unique_ents_full: [udefrakommende, boligområder, ghettoer, i, dag]
# Unique_ents_full ratio: [0.14285714285714285, 0.14285714285714285, 0.2857142857142857, 0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): [ghettoer]
# Unique_ents_partial: [udefrakommende, boligområder, ghettoer, i, dag]
# Unique_ents_partial ratio: [0.14285714285714285, 0.14285714285714285, 0.2857142857142857, 0.14285714285714285, 0.14285714285714285]
# Infreq ents (no overlaps): [udefrakommende, boligområder, i, dag]
# Current doc ents PRIOR to streamlining: (ghettoer,)
# Current doc ents AFTER streamlining: (ghettoer,)
#
#
#
#
# Current rater: 7
# Current rater_idx: 5
# Current doc index in rater: 9
# Current doc: Gav man dem mulighed for at bo andre steder?
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 7
# Current rater_idx: 5
# Current doc index in rater: 10
# Current doc: Nå nej
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 7
# Current rater_idx: 5
# Current doc index in rater: 11
# Current doc: Det er selvfølgelig anekdotisk, men jeg har mødt så mange gode mennesker i min barndom som både hed Abdi, Tarik, Muhammad og Eyman.
# Unique_ents_full: [Abdi, Tarik, Muhammad, Eyman]
# Unique_ents_full ratio: [1.0, 1.0, 1.0, 1.0]
# Freq ents (no duplicates): [Abdi, Tarik, Muhammad, Eyman]
# Unique_ents_partial: [Abdi, Tarik, Muhammad, Eyman]
# Unique_ents_partial ratio: [1.0, 1.0, 1.0, 1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (Abdi, Tarik, Muhammad, Eyman)
# Current doc ents AFTER streamlining: (Abdi, Tarik, Muhammad, Eyman)
#
#
#
#
# Current rater: 7
# Current rater_idx: 5
# Current doc index in rater: 12
# Current doc: Varme hjerter, svære kår, gode til fodbold.
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 7
# Current rater_idx: 5
# Current doc index in rater: 13
# Current doc: Flere af dem sælger hash osv i dag.
# Unique_ents_full: [dag, i]
# Unique_ents_full ratio: [0.2857142857142857, 0.14285714285714285]
# Freq ents (no duplicates): [dag]
# Unique_ents_partial: [dag, i]
# Unique_ents_partial ratio: [0.2857142857142857, 0.14285714285714285]
# Infreq ents (no overlaps): [i]
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: (dag,)
#
#
#
#
# Current rater: 7
# Current rater_idx: 5
# Current doc index in rater: 14
# Current doc: Så sørgeligt og jeg nægter tesen om at det skulle være selvforskyldt
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 7
# Current rater_idx: 5
# Current doc index in rater: 15
# Current doc: Deres forældre havde ingen muligheder, allerede dengang blev de set ned på i samfundet, på kommunen og i parlamentet.
# Unique_ents_full: [kommunen, parlamentet, dengang]
# Unique_ents_full ratio: [0.2857142857142857, 0.42857142857142855, 0.14285714285714285]
# Freq ents (no duplicates): [kommunen, parlamentet]
# Unique_ents_partial: [kommunen, parlamentet, dengang]
# Unique_ents_partial ratio: [0.2857142857142857, 0.42857142857142855, 0.14285714285714285]
# Infreq ents (no overlaps): [dengang]
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: (kommunen, parlamentet)
#
#
#
#
# Current rater: 7
# Current rater_idx: 5
# Current doc index in rater: 16
# Current doc: Svært at gro blomster direkte på beton
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 7
# Current rater_idx: 5
# Current doc index in rater: 17
# Current doc:
# @iNSiG9FiX @cekicozlem
# Unique_ents_full: [@iNSiG9FiX, @cekicozlem]
# Unique_ents_full ratio: [1.0, 1.0]
# Freq ents (no duplicates): [@iNSiG9FiX, @cekicozlem]
# Unique_ents_partial: [@iNSiG9FiX, @cekicozlem]
# Unique_ents_partial ratio: [1.0, 1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (@iNSiG9FiX, @cekicozlem)
# Current doc ents AFTER streamlining: (@iNSiG9FiX, @cekicozlem)
#
#
#
#
# Current rater: 7
# Current rater_idx: 5
# Current doc index in rater: 18
# Current doc: Deres forældre, bedsteforældre er det vel snarere nu, de havde alle de muligheder de valgte at forfølge.
# Unique_ents_full: [nu]
# Unique_ents_full ratio: [0.14285714285714285]
# Freq ents (no duplicates): []
# Unique_ents_partial: [nu]
# Unique_ents_partial ratio: [0.14285714285714285]
# Infreq ents (no overlaps): [nu]
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 7
# Current rater_idx: 5
# Current doc index in rater: 19
# Current doc: Det er på tide man lægger offerrollen på hylden.
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 9
# Current rater_idx: 6
# Current doc index in rater: 0
# Current doc: Hvordan kan statsministeren kalde børn,der er født på danske hospitaler for indvandrerdrenge!
# Unique_ents_full: [danske, statsministeren, hospitaler, indvandrerdrenge]
# Unique_ents_full ratio: [1.0, 0.2857142857142857, 0.2857142857142857, 0.2857142857142857]
# Freq ents (no duplicates): [danske, statsministeren, hospitaler, indvandrerdrenge]
# Unique_ents_partial: [danske, statsministeren, hospitaler, indvandrerdrenge]
# Unique_ents_partial ratio: [1.0, 0.2857142857142857, 0.2857142857142857, 0.2857142857142857]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (danske,)
# Current doc ents AFTER streamlining: (statsministeren, danske, hospitaler, indvandrerdrenge)
#
#
#
#
# Current rater: 9
# Current rater_idx: 6
# Current doc index in rater: 1
# Current doc: Det her er jo håbløst #dkpol  https://t.co/e7hAg155Gw
# Unique_ents_full: [dkpol, #dkpol]
# Unique_ents_full ratio: [0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): []
# Unique_ents_partial: [dkpol, #dkpol]
# Unique_ents_partial ratio: [0.14285714285714285, 0.14285714285714285]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 9
# Current rater_idx: 6
# Current doc index in rater: 2
# Current doc:
# @cekicozlem
# Unique_ents_full: [@cekicozlem]
# Unique_ents_full ratio: [1.0]
# Freq ents (no duplicates): [@cekicozlem]
# Unique_ents_partial: [@cekicozlem]
# Unique_ents_partial ratio: [1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (@cekicozlem,)
# Current doc ents AFTER streamlining: (@cekicozlem,)
#
#
#
#
# Current rater: 9
# Current rater_idx: 6
# Current doc index in rater: 3
# Current doc: Da jeg voksede op ude i vollsmose, kaldte man dem 2. Generationsindvandrere.
# Unique_ents_full: [vollsmose, vollsmose, 2., 2. Generationsindvandrere., 2., 2. Generationsindvandrere]
# Unique_ents_full ratio: [0.42857142857142855, 0.5714285714285714, 0.2857142857142857, 0.14285714285714285, 0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): [2.]
# Unique_ents_partial: [vollsmose, 2., 2. Generationsindvandrere., 2. Generationsindvandrere]
# Unique_ents_partial ratio: [1.0, 0.42857142857142855, 0.14285714285714285, 0.14285714285714285]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (vollsmose,)
# Current doc ents AFTER streamlining: (vollsmose, 2.)
#
#
#
#
# Current rater: 9
# Current rater_idx: 6
# Current doc index in rater: 4
# Current doc: Vi må så være på 3. Generation nu?
# Unique_ents_full: [3., 3., 3. Generation]
# Unique_ents_full ratio: [0.2857142857142857, 0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): [3.]
# Unique_ents_partial: [3., 3. Generation]
# Unique_ents_partial ratio: [0.42857142857142855, 0.14285714285714285]
# Infreq ents (no overlaps): [3. Generation]
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: (3.,)
#
#
#
#
# Current rater: 9
# Current rater_idx: 6
# Current doc index in rater: 5
# Current doc: Åndssvagt ord, som ingen problemer løser.
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 9
# Current rater_idx: 6
# Current doc index in rater: 6
# Current doc: For der ér problemer blandt disse sociale lag, og dem kommer vi først rigtig til livs når vi kigger lidt bag tæppet
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 9
# Current rater_idx: 6
# Current doc index in rater: 7
# Current doc: Man kunne spørge sig selv, hvad dee mon ligger til grund for at så mange går ud af den kriminelle sti - som om de intet har at miste - kunne det tænkes at dk lod dem og deres forældre i stikken da de startede deres nye liv her?
# Unique_ents_full: [dk]
# Unique_ents_full ratio: [1.0]
# Freq ents (no duplicates): [dk]
# Unique_ents_partial: [dk]
# Unique_ents_partial ratio: [1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (dk,)
# Current doc ents AFTER streamlining: (dk,)
#
#
#
#
# Current rater: 9
# Current rater_idx: 6
# Current doc index in rater: 8
# Current doc: Man kunne også spørge om det mon er os eller dem som har skabt disse parallelsamfund.
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 9
# Current rater_idx: 6
# Current doc index in rater: 9
# Current doc: Hvem har besluttet at internere alle udefrakommende i disse nedslidte boligområder, vi i dag kalder for ghettoer?
# Unique_ents_full: [udefrakommende, boligområder, ghettoer, i, dag]
# Unique_ents_full ratio: [0.14285714285714285, 0.14285714285714285, 0.2857142857142857, 0.14285714285714285, 0.14285714285714285]
# Freq ents (no duplicates): [ghettoer]
# Unique_ents_partial: [udefrakommende, boligområder, ghettoer, i, dag]
# Unique_ents_partial ratio: [0.14285714285714285, 0.14285714285714285, 0.2857142857142857, 0.14285714285714285, 0.14285714285714285]
# Infreq ents (no overlaps): [udefrakommende, boligområder, i, dag]
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: (ghettoer,)
#
#
#
#
# Current rater: 9
# Current rater_idx: 6
# Current doc index in rater: 10
# Current doc: Gav man dem mulighed for at bo andre steder?
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 9
# Current rater_idx: 6
# Current doc index in rater: 11
# Current doc: Nå nej
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 9
# Current rater_idx: 6
# Current doc index in rater: 12
# Current doc: Det er selvfølgelig anekdotisk, men jeg har mødt så mange gode mennesker i min barndom som både hed Abdi, Tarik, Muhammad og Eyman.
# Unique_ents_full: [Abdi, Tarik, Muhammad, Eyman]
# Unique_ents_full ratio: [1.0, 1.0, 1.0, 1.0]
# Freq ents (no duplicates): [Abdi, Tarik, Muhammad, Eyman]
# Unique_ents_partial: [Abdi, Tarik, Muhammad, Eyman]
# Unique_ents_partial ratio: [1.0, 1.0, 1.0, 1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (Abdi, Tarik, Muhammad, Eyman)
# Current doc ents AFTER streamlining: (Abdi, Tarik, Muhammad, Eyman)
#
#
#
#
# Current rater: 9
# Current rater_idx: 6
# Current doc index in rater: 13
# Current doc: Varme hjerter, svære kår, gode til fodbold.
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 9
# Current rater_idx: 6
# Current doc index in rater: 14
# Current doc: Flere af dem sælger hash osv i dag.
# Unique_ents_full: [dag, i]
# Unique_ents_full ratio: [0.2857142857142857, 0.14285714285714285]
# Freq ents (no duplicates): [dag]
# Unique_ents_partial: [dag, i]
# Unique_ents_partial ratio: [0.2857142857142857, 0.14285714285714285]
# Infreq ents (no overlaps): [i]
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: (dag,)
#
#
#
#
# Current rater: 9
# Current rater_idx: 6
# Current doc index in rater: 15
# Current doc: Så sørgeligt og jeg nægter tesen om at det skulle være selvforskyldt
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 9
# Current rater_idx: 6
# Current doc index in rater: 16
# Current doc: Deres forældre havde ingen muligheder, allerede dengang blev de set ned på i samfundet, på kommunen og i parlamentet.
# Unique_ents_full: [kommunen, parlamentet, dengang]
# Unique_ents_full ratio: [0.2857142857142857, 0.42857142857142855, 0.14285714285714285]
# Freq ents (no duplicates): [kommunen, parlamentet]
# Unique_ents_partial: [kommunen, parlamentet, dengang]
# Unique_ents_partial ratio: [0.2857142857142857, 0.42857142857142855, 0.14285714285714285]
# Infreq ents (no overlaps): [dengang]
# Current doc ents PRIOR to streamlining: (parlamentet,)
# Current doc ents AFTER streamlining: (kommunen, parlamentet)
#
#
#
#
# Current rater: 9
# Current rater_idx: 6
# Current doc index in rater: 17
# Current doc: Svært at gro blomster direkte på beton
# Unique_ents_full: []
# Unique_ents_full ratio: []
# Freq ents (no duplicates): []
# Unique_ents_partial: []
# Unique_ents_partial ratio: []
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Current rater: 9
# Current rater_idx: 6
# Current doc index in rater: 18
# Current doc:
# @iNSiG9FiX @cekicozlem
# Unique_ents_full: [@iNSiG9FiX, @cekicozlem]
# Unique_ents_full ratio: [1.0, 1.0]
# Freq ents (no duplicates): [@iNSiG9FiX, @cekicozlem]
# Unique_ents_partial: [@iNSiG9FiX, @cekicozlem]
# Unique_ents_partial ratio: [1.0, 1.0]
# Infreq ents (no overlaps): []
# Current doc ents PRIOR to streamlining: (@iNSiG9FiX, @cekicozlem)
# Current doc ents AFTER streamlining: (@iNSiG9FiX, @cekicozlem)
#
#
#
#
# Current rater: 9
# Current rater_idx: 6
# Current doc index in rater: 19
# Current doc: Deres forældre, bedsteforældre er det vel snarere nu, de havde alle de muligheder de valgte at forfølge.
# Unique_ents_full: [nu]
# Unique_ents_full ratio: [0.14285714285714285]
# Freq ents (no duplicates): []
# Unique_ents_partial: [nu]
# Unique_ents_partial ratio: [0.14285714285714285]
# Infreq ents (no overlaps): [nu]
# Current doc ents PRIOR to streamlining: ()
# Current doc ents AFTER streamlining: ()
#
#
#
#
# Doc does not exist for rater

# %% [markdown]
# # Save all streamlined docs as jsonl

# %%
# Save all streamlined docs as jsonl
for rater_idx in raters_idx:
    db = DocBin()
    savepath = f"./data/DANSK-multi/streamlined/rater_{raters_lookup[rater_idx]}/data.jsonl"
    for doc in streamlined_data[rater_idx]:
        db.add(doc)
    examples = []
    for doc in db.get_docs(nlp.vocab):
        spans = [{"start": ent.start_char, "end": ent.end_char, "label": ent.label_} for ent in doc.ents]
        examples.append({"text": doc.text, "spans": spans})
    with open(savepath, 'w') as outfile:
        for entry in examples:
            json.dump(entry, outfile)
            outfile.write('\n')
